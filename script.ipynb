# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.2/825.2 kB 6.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# %%
# model = YOLO('/content/drive/MyDrive/yolov8n.pt')

# %%
# model.train(data='/content/drive/MyDrive/yolov8/data.yaml', epochs=100, imgsz=[640,640])

# %%
# !yolo detect train model = yolov8n.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=200 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 133MB/s]
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/runs/detect
# Out:
# /content/runs/detect

# %%
# !zip -r train.zip train/
# Out:
#   adding: train/ (stored 0%)
#   adding: train/events.out.tfevents.1721614073.7136d1745ae5.1106.0 (deflated 84%)
#   adding: train/results.png (deflated 8%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/val_batch2_pred.jpg (deflated 6%)
#   adding: train/labels.jpg (deflated 28%)
#   adding: train/confusion_matrix.png (deflated 27%)
#   adding: train/train_batch1.jpg (deflated 5%)
#   adding: train/val_batch1_labels.jpg (deflated 7%)
#   adding: train/val_batch0_pred.jpg (deflated 6%)
#   adding: train/R_curve.png (deflated 10%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 9%)
#   adding: train/weights/last.pt (deflated 9%)
#   adding: train/confusion_matrix_normalized.png (deflated 25%)
#   adding: train/labels_correlogram.jpg (deflated 34%)
#   adding: train/results.csv (deflated 86%)
#   adding: train/train_batch2.jpg (deflated 5%)
#   adding: train/PR_curve.png (deflated 13%)
#   adding: train/train_batch0.jpg (deflated 4%)
# ...

# %%
from google.colab import files
files.download('train.zip')
